# %%
import pandas as pd
behaviour = pd.read_csv("C:/Users/adith/spotify_analytics/data/cleaned/spotify_user_behavior_cleaned1.csv")
churn = pd.read_csv("C:/Users/adith/spotify_analytics/data/cleaned/spotify_churn_processed.csv")

# %%
behaviour.head()
# Out:
#      age  gender spotify_usage_period  \
# 0  20-35  Female    More than 2 years
# 1  12-20    Male    More than 2 years
# 2  35-60  Others   6 months to 1 year
# 3  20-35  Female    1 year to 2 years
# 4  20-35  Female    1 year to 2 years
#
#                          spotify_listening_device spotify_subscription_plan  \
# 0              Smart speakers or voice assistants                      Free
# 1                              Computer or laptop                      Free
# 2              Smart speakers or voice assistants                      Free
# 3  Smartphone, Smart speakers or voice assistants                      Free
# 4                                      Smartphone                      Free
#
#   premium_sub_willingness preffered_premium_plan preferred_listening_content  \
# 0                     Yes                 Family                     Podcast
# 1                     Yes             Individual                     Podcast
# ...

# %%
behaviour['preffered_premium_plan'].unique()
# Out:
# array(['Family', 'Individual', 'Student', 'No Interest', 'Unknown', 'Duo'],
#       dtype=object)

# %%
audio_features = pd.read_csv("C:/Users/adith/spotify_analytics/data/cleaned/audio_features_cleaned.csv")
spotify_streams = pd.read_csv("C:/Users/adith/spotify_analytics/data/cleaned/spotify_global_streams_processed.csv")

# %%
audio_features.head()
# Out:
#                  track_id                 artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# ...

# %%
spotify_streams.head()
# Out:
#          Country        Artist                    Album      Genre  \
# 0        Germany  Taylor Swift  1989 (Taylor's Version)      K-pop
# 1         Brazil    The Weeknd              After Hours        R&B
# 2  United States   Post Malone                   Austin  Reggaeton
# 3          Italy    Ed Sheeran        Autumn Variations      K-pop
# 4          Italy    Ed Sheeran        Autumn Variations        R&B
#
#    Release Year  Monthly Listeners (Millions)  Total Streams (Millions)  \
# 0          2020                         23.10                   3695.53
# 1          2023                         60.60                   2828.16
# 2          2019                         42.84                   1425.46
# 3          2019                         73.24                   2704.33
# 4          2019                          7.89                   3323.25
#
#    Total Hours Streamed (Millions)  Avg Stream Duration (Min) Platform Type  \
# ...
